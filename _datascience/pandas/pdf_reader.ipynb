# %%
# %pip install textract
# Out:
# Looking in indexes: https://pypi.python.org/simple/
# ...
#   Using cached pdfminer.six-20181108-py2.py3-none-any.whl (5.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import textract
text = textract.process('data/pdf/doc.pdf', method='pdfminer')
print(text.decode('UTF-8'))
# Out:
# 174085808607093
#
# E ATTESTATIONS.COM
#
# N/REF :
# Souscripteur :
# Contrat :
#  Votre espace : https://helium.gestion-sante.com
# Identifiant :
#
# 4432179 ENSEMBLE DU PERSONNEL
#
# 1740858086070
#
# AUT_20181112_13215283.409.1
#
# MR DAGOURY Vincent
# 13 RUE DE PERTHUIS
#
# 91370 VERRIERES LE BUISSON
#
# Reims, le 12/11/2018
#
# Cher Client,
#
# Nous avons le plaisir de vous adresser votre nouvelle attestation de Tiers-Payant pour la période du 01/01/2019
# au 31/12/2019.
#
# N'oubliez  pas  de  la  présenter  systématiquement  pour  éviter  l'avance  des  frais  (nous  vous  conseillons  de  la
# conserver avec votre carte vitale).
#
# Nous  vous  remercions  de  la  confiance  que  vous  nous  accordez  et  vous  prions  d'agréer,  l'expression  de  nos
# sentiments dévoués.
#
# Effectuez rapidement l'ensemble de vos démarches sur votre espace Assuré, accessible 7j/7 et 24h/24.
#
# ...
